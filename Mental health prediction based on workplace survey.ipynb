# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score

# %%
dataset= pd.read_csv("survey.csv")
dataset
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1095
# dtype: int64

# %%
dataset.dropna()
# Out:
#                 Timestamp  Age  Gender        Country state self_employed  \
# 24    2014-08-27 11:36:48   33    male  United States    CA            No
# 25    2014-08-27 11:37:08   35    male  United States    TN            No
# 33    2014-08-27 11:39:36   42    Male  United States    WA            No
# 45    2014-08-27 11:43:36   38  Female  United States    TX            No
# 49    2014-08-27 11:44:43   30    male  United States    IL            No
# ...                   ...  ...     ...            ...   ...           ...
# 1186  2014-11-06 11:24:38   56  female  United States    OR           Yes
# 1190  2015-01-03 03:38:30   44       M  United States    OH            No
# 1219  2015-02-21 09:48:13   38    Male  United States    TX            No
# 1221  2015-02-21 10:45:51   46    male  United States    MD            No
# 1249  2015-07-22 18:57:54   30       M  United States    CA            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
for i in dataset.columns:
    if(dataset[i].dtype == 'object'):
        dataset[i]= dataset[i].fillna("unknown")
    else:
        dataset[i]= dataset[i].fillna(dataset[i].mean())

# %%
dataset
# Out:
#                 Timestamp  Age  Gender         Country    state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States       IL       unknown
# 1     2014-08-27 11:29:37   44       M   United States       IN       unknown
# 2     2014-08-27 11:29:44   32    Male          Canada  unknown       unknown
# 3     2014-08-27 11:29:46   31    Male  United Kingdom  unknown       unknown
# 4     2014-08-27 11:30:22   31    Male   United States       TX       unknown
# ...                   ...  ...     ...             ...      ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom  unknown            No
# 1255  2015-09-26 01:07:35   32    Male   United States       IL            No
# 1256  2015-11-07 12:36:58   34    male   United States       CA            No
# 1257  2015-11-30 21:25:06   46       f   United States       NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States       IL            No
#
# ...

# %%
dataset['treatment'].value_counts()
# Out:
# treatment
# Yes    637
# No     622
# Name: count, dtype: int64

# %%
for i in dataset.columns:
    if(dataset[i].dtype == 'object'):
        dataset[i]= LabelEncoder().fit_transform(dataset[i])

# %%
dataset
# Out:
#       Timestamp  Age  Gender  Country  state  self_employed  family_history  \
# 0             0   37      10       45     10              2               0
# 1             1   44      16       45     11              2               0
# 2             2   32      20        7     45              2               0
# 3             3   31      20       44     45              2               1
# 4             4   31      20       45     37              2               0
# ...         ...  ...     ...      ...    ...            ...             ...
# 1254       1241   26      39       44     45              0               0
# 1255       1242   32      20       45     10              0               1
# 1256       1243   34      39       45      2              0               1
# 1257       1244   46      33       45     22              0               0
# 1258       1245   25      20       45     10              0               1
#
# ...

# %%
X= dataset.drop('treatment', axis=1)
X
# Out:
#       Timestamp  Age  Gender  Country  state  self_employed  family_history  \
# 0             0   37      10       45     10              2               0
# 1             1   44      16       45     11              2               0
# 2             2   32      20        7     45              2               0
# 3             3   31      20       44     45              2               1
# 4             4   31      20       45     37              2               0
# ...         ...  ...     ...      ...    ...            ...             ...
# 1254       1241   26      39       44     45              0               0
# 1255       1242   32      20       45     10              0               1
# 1256       1243   34      39       45      2              0               1
# 1257       1244   46      33       45     22              0               0
# 1258       1245   25      20       45     10              0               1
#
# ...

# %%
Y= dataset['treatment']
Y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1254    1
# 1255    1
# 1256    1
# 1257    0
# 1258    1
# Name: treatment, Length: 1259, dtype: int64

# %%
corr = X.corrwith(Y)
corr
# Out:
# Timestamp                    0.062499
# Age                          0.027860
# Gender                      -0.051068
# Country                      0.077681
# state                       -0.102083
# self_employed                0.015943
# family_history               0.377918
# work_interfere              -0.035881
# no_employees                -0.050114
# remote_work                  0.026937
# tech_company                -0.031525
# benefits                     0.226140
# care_options                 0.236578
# wellness_program             0.094713
# seek_help                    0.089935
# anonymity                    0.142889
# leave                        0.061549
# mental_health_consequence    0.030221
# phys_health_consequence     -0.008933
# coworkers                    0.068433
# supervisor                  -0.036199
# mental_health_interview      0.098413
# phys_health_interview        0.051859
# mental_vs_physical           0.062642
# obs_consequence              0.156972
# ...

# %%
scaler= StandardScaler()
X= scaler.fit_transform(X)
X
# Out:
# array([[-1.72529157, -0.02819419, -1.32286947, ...,  1.4208029 ,
#         -0.41371825,  0.32869357],
#        [-1.72250954, -0.02819419, -0.7069708 , ..., -0.97704006,
#         -0.41371825,  0.32869357],
#        [-1.71972751, -0.02819419, -0.29637168, ...,  0.22188142,
#         -0.41371825,  0.32869357],
#        ...,
#        [ 1.73277145, -0.02819419,  1.65397411, ...,  0.22188142,
#         -0.41371825,  0.32869357],
#        [ 1.73555348, -0.02819419,  1.03807544, ...,  0.22188142,
#         -0.41371825,  0.32869357],
#        [ 1.73833551, -0.0281942 , -0.29637168, ..., -0.97704006,
#         -0.41371825,  0.32869357]], shape=(1259, 26))

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X,Y, test_size= 0.1, stratify= Y, random_state= 42)

# %%
model= RandomForestClassifier(max_depth=6)
model
# Out:
# RandomForestClassifier(max_depth=6)

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(max_depth=6)

# %%
predict_X_train= model.predict(X_train)
accuracy_X_train= accuracy_score(Y_train, predict_X_train)
accuracy_X_train*100
# Out:
# 87.90820829655782

# %%
predict_X_test= model.predict(X_test)
accuracy_X_test= accuracy_score(Y_test, predict_X_test)
accuracy_X_test*100
# Out:
# 84.12698412698413

# %%
predict_X_train= model.predict(X_train)
f1_X_train= f1_score(Y_train, predict_X_train)
f1_X_train*100
# Out:
# 88.45829823083403

# %%
predict_X_test= model.predict(X_test)
f1_X_test= f1_score(Y_test, predict_X_test)
f1_X_test*100
# Out:
# 85.07462686567165
